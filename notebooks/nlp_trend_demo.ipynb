# %% [markdown]
# # NLP Trend Demo (OpenAlex)
#
# This notebook fetches approximate counts of NLP-related works from the OpenAlex API and plots a simple trend.

# %%
from src.api.openalex_client import OpenAlexClient
from src.data.process import nlp_dict_to_dataframe
from src.viz.charts import plot_nlp_trend
import pandas as pd

# %% [markdown]
# ## 1) Fetch counts for a small year range

# %%
client = OpenAlexClient()
year_counts = client.fetch_nlp_counts_per_year(2019, 2021)
year_counts

# %% [markdown]
# ## 2) Convert to DataFrame and display

# %%
df = nlp_dict_to_dataframe(year_counts)
df

# %% [markdown]
# ## 3) Plot the trend

# %%
plot_nlp_trend(df)

# %% [markdown]
# Notes:
# - OpenAlex does not require an API key.
# - Counts are approximate and depend on the selected filter (we use the NLP concept id).
